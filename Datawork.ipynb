# %%
import pandas as pd
import numpy as np
from scipy.stats import linregress
from multiprocessing import Pool
import time
from datetime import datetime
import streamlit as st
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima
from joblib import Parallel, delayed
import aiohttp
import asyncio
import requests
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn")

# %%
# Чтение данных
data = pd.read_csv("temperature_data.csv", parse_dates=["timestamp"])
data = data.sort_values(by=["city", "timestamp"])

# %%
def analyze_city(city_data):
    
    rolling_mean = city_data['temperature'].rolling(window=30, min_periods=1).mean()
    rolling_std = city_data['temperature'].rolling(window=30, min_periods=1).std()

    seasonal_stats = city_data.groupby('season')['temperature'].agg(['mean', 'std']).reset_index()
    seasonal_profile = {
        row['season']: {"mean": row['mean'], "std": row['std']}
        for _, row in seasonal_stats.iterrows()
    }

    anomalies = city_data[np.abs(city_data['temperature'] - rolling_mean) > 2 * rolling_std]

    # Автоподбор параметров SARIMA
    stepwise_fit = auto_arima(city_data['temperature'], seasonal=True, m=12, trace=True, 
                              suppress_warnings=True, stepwise=True)
    order = stepwise_fit.order
    seasonal_order = stepwise_fit.seasonal_order
    model = SARIMAX(city_data['temperature'], order=order, seasonal_order=seasonal_order)
    results = model.fit(disp=0) 

    return rolling_mean, rolling_std, anomalies, seasonal_profile, order, seasonal_order

# %%
def parallel_analyze(cities_data):
    start_time = time.time()
    results = Parallel(n_jobs=-1)(delayed(analyze_city)(data) for data in cities_data)
    end_time = time.time()
    print(f"Время параллельного выполнения: {end_time - start_time:.2f} секунд")
    return results

def sequential_analyze(cities_data):
    start_time = time.time()
    results = [analyze_city(data) for data in cities_data]
    end_time = time.time()
    print(f"Время последовательного выполнения {end_time - start_time:.2f} секунд")
    return results

# %%
cities = data["city"].unique()

cities_data = [
    data[data["city"] == city].sort_values(by="timestamp").reset_index(drop=True)
    for city in cities
]
sequential_results = sequential_analyze(cities_data)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=23279.264, Time=7.57 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=28121.186, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=24452.827, Time=1.78 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=25729.595, Time=1.72 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=31374.708, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=23279.174, Time=5.18 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=23277.231, Time=0.85 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=23279.208, Time=3.89 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=23275.120, Time=1.42 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=23277.116, Time=4.88 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=23277.116, Time=3.43 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=7.43 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=25582.675, Time=0.99 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=23273.422, Time=1.09 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=23275.420, Time=3.63 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=23275.420, Time=2.99 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=5.16 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=26385.773, Time=0.81 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=24484.537, Time=0.27 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=23275.138, Time=1.48 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=23802.417, Time=0.71 sec
#  ARIMA(1,0,1)(0,0,0)[12]             : AIC=23284.412, Time=0.41 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[12] intercept
# Total fit time: 55.846 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=22847.217, Time=11.73 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=26075.006, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=23967.437, Time=2.49 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=24584.254, Time=2.44 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=29350.117, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=22849.045, Time=8.88 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=22849.040, Time=8.00 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : AIC=inf, Time=29.91 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=32.40 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=22847.211, Time=2.86 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=22846.185, Time=1.47 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=22847.778, Time=4.94 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=22847.792, Time=4.35 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=10.68 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=24497.606, Time=1.07 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=22846.201, Time=1.29 sec
#  ARIMA(1,0,3)(0,0,0)[12] intercept   : AIC=22847.850, Time=2.19 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=25014.278, Time=0.59 sec
#  ARIMA(0,0,3)(0,0,0)[12] intercept   : AIC=24114.392, Time=1.52 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=22846.142, Time=1.41 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=22847.734, Time=5.54 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=22847.748, Time=4.64 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=22843.777, Time=10.74 sec
#  ARIMA(2,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=25.65 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=25.05 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=22848.698, Time=9.23 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=22848.548, Time=9.94 sec
#  ARIMA(2,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=19.30 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=22843.849, Time=7.94 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=23377.797, Time=3.66 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=9.45 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=23826.539, Time=2.46 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=23124.269, Time=5.78 sec
#  ARIMA(3,0,2)(1,0,1)[12] intercept   : AIC=22849.600, Time=9.60 sec
#  ARIMA(2,0,1)(1,0,1)[12]             : AIC=22857.447, Time=4.16 sec
#
# Best model:  ARIMA(2,0,1)(1,0,1)[12] intercept
# Total fit time: 281.539 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=8.47 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=26128.949, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=23972.385, Time=2.79 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=24575.685, Time=1.03 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=34330.235, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=24093.500, Time=0.25 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=23896.461, Time=4.81 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=23872.942, Time=11.81 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=23872.706, Time=4.84 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=24007.059, Time=1.40 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=23872.608, Time=10.82 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=23950.164, Time=3.64 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=14.60 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=24372.439, Time=12.43 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=9.91 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=12.18 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=24092.351, Time=15.21 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=17.55 sec
#  ARIMA(1,0,0)(1,0,2)[12]             : AIC=24193.344, Time=5.50 sec
#
# Best model:  ARIMA(1,0,0)(1,0,2)[12] intercept
# Total fit time: 137.328 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=8.17 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=26225.464, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=24144.202, Time=2.20 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=24748.722, Time=0.97 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=35499.492, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=24214.033, Time=0.16 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=24080.102, Time=6.15 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=24033.991, Time=12.40 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=24036.221, Time=4.43 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=15.78 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=24033.217, Time=10.18 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=24126.107, Time=3.94 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=24161.590, Time=1.76 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=24557.266, Time=12.33 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=13.81 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=16.37 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=24271.519, Time=15.07 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=18.32 sec
#  ARIMA(1,0,0)(1,0,2)[12]             : AIC=24346.901, Time=6.63 sec
#
# Best model:  ARIMA(1,0,0)(1,0,2)[12] intercept
# Total fit time: 148.750 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=8.80 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=24334.977, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=23488.745, Time=2.06 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=23678.783, Time=1.43 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=29237.409, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=23573.822, Time=0.17 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=23420.527, Time=4.98 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=23380.519, Time=9.70 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=23383.828, Time=3.31 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=23366.170, Time=14.74 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=23379.666, Time=8.99 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=9.20 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=14.96 sec
#  ARIMA(1,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=18.09 sec
#  ARIMA(0,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=14.29 sec
#  ARIMA(2,0,1)(2,0,2)[12] intercept   : AIC=22718.140, Time=20.18 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=19.05 sec
#  ARIMA(2,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=17.74 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=7.79 sec
#  ARIMA(3,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=21.97 sec
#  ARIMA(2,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=29.31 sec
#  ARIMA(1,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=19.11 sec
#  ARIMA(3,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=20.21 sec
#  ARIMA(3,0,2)(2,0,2)[12] intercept   : AIC=inf, Time=24.23 sec
#  ARIMA(2,0,1)(2,0,2)[12]             : AIC=inf, Time=12.54 sec
#
# Best model:  ARIMA(2,0,1)(2,0,2)[12] intercept
# Total fit time: 302.948 seconds
# c:\Users\eduar\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=9.06 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=23564.251, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=22993.428, Time=2.82 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=23108.677, Time=1.44 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=32367.251, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=23118.991, Time=0.24 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=22925.589, Time=7.03 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=22901.556, Time=13.89 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=22902.256, Time=5.32 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=16.90 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=22901.364, Time=12.29 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=22962.913, Time=4.29 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=23025.824, Time=1.72 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=23017.766, Time=11.88 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=21.68 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=24.94 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=22934.982, Time=24.44 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=29.44 sec
#  ARIMA(1,0,0)(1,0,2)[12]             : AIC=inf, Time=18.27 sec
#
# Best model:  ARIMA(1,0,0)(1,0,2)[12] intercept
# Total fit time: 205.738 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=22599.793, Time=14.31 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=23186.491, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=22845.742, Time=3.12 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=22909.178, Time=2.48 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=31158.166, Time=0.14 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=inf, Time=10.06 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC
sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=23228.141, Time=1.14 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=23228.256, Time=4.53 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=5.73 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : AIC=23135.179, Time=2.46 sec
#  ARIMA(5,0,1)(1,0,0)[12] intercept   : AIC=23136.427, Time=9.78 sec
#  ARIMA(5,0,1)(0,0,1)[12] intercept   : AIC=23136.405, Time=6.25 sec
#  ARIMA(5,0,1)(1,0,1)[12] intercept   : AIC=23139.039, Time=11.33 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=23134.727, Time=2.32 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : AIC=23135.904, Time=6.93 sec
#  ARIMA(4,0,1)(0,0,1)[12] intercept   : AIC=23135.879, Time=5.51 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : AIC=23138.323, Time=9.73 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=23132.732, Time=1.89 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=23133.904, Time=5.68 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=23133.879, Time=4.27 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=7.82 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=23133.196, Time=0.96 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=23136.702, Time=1.14 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=23134.973, Time=0.87 sec
#  ARIMA(4,0,2)(0,0,0)[12] intercept   : AIC=23136.635, Time=1.54 sec
#  ARIMA(3,0,1)(0,0,0)[12]             : AIC=23142.928, Time=1.04 sec
#
# Best model:  ARIMA(3,0,1)(0,0,0)[12] intercept
# Total fit time: 330.703 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=8.71 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=25110.066, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=23690.233, Time=1.55 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=24048.483, Time=1.41 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=29816.835, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=23805.584, Time=0.15 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=23606.081, Time=3.86 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=23564.520, Time=10.43 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=23567.725, Time=3.36 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=23532.063, Time=13.72 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=23563.481, Time=7.46 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=10.34 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : AIC=23244.165, Time=17.23 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=12.65 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=15.15 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=23300.035, Time=6.62 sec
#  ARIMA(3,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=20.92 sec
#  ARIMA(2,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=18.65 sec
#  ARIMA(1,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=28.26 sec
#  ARIMA(3,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=23.65 sec
#  ARIMA(2,0,0)(2,0,2)[12]             : AIC=inf, Time=15.08 sec
#
# Best model:  ARIMA(2,0,0)(2,0,2)[12] intercept
# Total fit time: 219.270 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=9.23 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=23601.440, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=23085.489, Time=3.33 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=23187.750, Time=0.99 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=34055.795, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=23170.927, Time=0.09 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=23039.043, Time=10.43 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=23042.431, Time=13.81 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=22996.108, Time=6.56 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=23103.097, Time=3.08 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=22992.829, Time=12.43 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=23071.535, Time=5.70 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=22990.684, Time=13.73 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=23164.015, Time=14.07 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=19.79 sec
#  ARIMA(1,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=17.86 sec
#  ARIMA(0,0,1)(2,0,2)[12] intercept   : AIC=23060.200, Time=17.96 sec
#  ARIMA(2,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=21.31 sec
#  ARIMA(1,0,0)(2,0,2)[12]             : AIC=23315.040, Time=6.35 sec
#
# Best model:  ARIMA(1,0,0)(2,0,2)[12] intercept
# Total fit time: 176.799 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=10.84 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=22072.922, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=22075.442, Time=3.57 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=22075.372, Time=0.84 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=34657.643, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=22074.903, Time=2.74 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=22074.904, Time=0.45 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=5.13 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=22073.472, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=22073.401, Time=0.27 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=22075.485, Time=0.34 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[12] intercept
# Total fit time: 24.360 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=9.12 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=24400.345, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=23447.657, Time=2.42 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=23688.184, Time=1.03 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=32194.633, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=23543.239, Time=0.18 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=23353.405, Time=5.58 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=23310.008, Time=12.49 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=23320.240, Time=6.27 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=23297.142, Time=14.31 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=23308.128, Time=12.39 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=11.70 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=17.93 sec
#  ARIMA(1,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=16.33 sec
#  ARIMA(0,0,1)(2,0,2)[12] intercept   : AIC=23491.859, Time=16.70 sec
#  ARIMA(2,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=19.03 sec
#  ARIMA(1,0,0)(2,0,2)[12]             : AIC=23627.501, Time=6.06 sec
#
# Best model:  ARIMA(1,0,0)(2,0,2)[12] intercept
# Total fit time: 151.620 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=10.76 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=26413.293, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=24013.405, Time=2.21 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=24730.145, Time=1.50 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=31780.704, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=24071.519, Time=0.29 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=23924.183, Time=4.62 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=23876.494, Time=7.46 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=23887.996, Time=3.21 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=13.92 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=23874.054, Time=6.69 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=23977.541, Time=4.07 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=24030.120, Time=1.41 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=24560.442, Time=10.48 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=23460.337, Time=12.79 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=23485.584, Time=3.79 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=23469.171, Time=6.25 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : AIC=23487.791, Time=17.01 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=23498.303, Time=1.63 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=23461.490, Time=15.44 sec
#  ARIMA(3,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=8.21 sec
#  ARIMA(2,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=15.71 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=14.23 sec
#  ARIMA(3,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=18.46 sec
#  ARIMA(2,0,0)(1,0,2)[12]             : AIC=inf, Time=10.09 sec
#
# Best model:  ARIMA(2,0,0)(1,0,2)[12] intercept
# Total fit time: 190.323 seconds
# Время последовательного выполнения 2847.77 секунд

# %%
parallel_results = parallel_analyze(cities_data)
# Out:
# Время параллельного выполнения: 1809.15 секунд

# %% [markdown]
# Как видно удалось ускорить обработку почти в 2 раза при помощи распаралеливания

# %%
API_KEY = ''

# %%
async def fetch_temperature_async(city):
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&units=metric&appid={API_KEY}"
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            data = await response.json()
            return data['main']['temp']

def fetch_temperature_sync(city):
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&units=metric&appid={API_KEY}"
    response = requests.get(url)
    data = response.json()
    return data['main']['temp']

# %%
# Определение текущего сезона для определения аномальности
def get_current_season():
    current_date = datetime.now()
    if current_date.month in [12, 1, 2]:
        return 'winter'
    elif current_date.month in [3, 4, 5]:
        return 'spring'
    elif current_date.month in [6, 7, 8]:
        return 'summer'
    else:
        return 'autumn'

def is_temperature_normal(city, current_temp, data):
    city_data = data[data['city'] == city]
    current_season = get_current_season() 
    seasonal_stats = city_data.groupby('season')['temperature'].agg(['mean', 'std'])

    mean = seasonal_stats.loc[current_season, 'mean']
    std = seasonal_stats.loc[current_season, 'std']
    
    return abs(current_temp - mean) <= 2 * std

# %%
async def fetch_all_temperatures_async(cities):
    tasks = [fetch_temperature_async(city) for city in cities]
    temperatures = await asyncio.gather(*tasks)
    return dict(zip(cities, temperatures))
    
def fetch_all_temperatures_sync(cities):
    temperatures = {city: fetch_temperature_sync(city) for city in cities}
    return temperatures
    
# Сравним синхронные и асинхронные запросы, сделав вызовы по всем городам.
start_time = time.time()
async_temperatures = await fetch_all_temperatures_async(cities)
async_time = time.time() - start_time
print(f"Время параллельного выполнения:  {async_time:.2f} секунд")


start_time = time.time()
sync_temperatures = fetch_all_temperatures_sync(cities)
sync_time = time.time() - start_time
print(f"Время последовательного выполнения: {sync_time:.2f} секунд")
# Out:
# Время параллельного выполнения:  0.33 секунд
# Время последовательного выполнения: 4.09 секунд

# %% [markdown]
# Как видно параллельное выполнение нескольких запросов также увеличивает скорость выполнения. Однако так как в streamlit приложении используются запросы по одному по одному городу, то можно ограничиться последовательными. Sarimax доло обучается поэтому в приложении streamlit используем более простую модель - Холта-Винтерса.
